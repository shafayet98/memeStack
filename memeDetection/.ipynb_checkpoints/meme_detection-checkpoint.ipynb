# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import keras_preprocessing
from PIL import Image, ImageFile
from keras_preprocessing import image
from keras_preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# path selections
train_dir = 'dataset/train'
validation_dir = 'dataset/val'

# %%
# looking into some of data from training set
img_path_meme_true = 'dataset/train/meme_true/12.jpg'
img = mpimg.imread(img_path_meme_true)
plt.title("Meme")
plt.imshow(img)
plt.show()

img_path_meme_false = 'dataset/train/meme_false/12.jpg'
img = mpimg.imread(img_path_meme_false)
plt.title("Not a meme")
plt.imshow(img)
plt.show()

# %%
training_datagen = ImageDataGenerator(
    rescale = 1./255,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2)

validation_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = training_datagen.flow_from_directory(
    train_dir,
    target_size=(80,80),
    class_mode='categorical',
    batch_size=64
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(80,80),
    class_mode='categorical',
    batch_size=64
)
# Out:
# Found 5579 images belonging to 2 classes.
# Found 582 images belonging to 2 classes.

# %%
model = tf.keras.Sequential()

# first conv2d and maxpooling layer
model.add(layers.Conv2D(64, (3,3), activation='relu', input_shape=(80, 80, 3)))
model.add(layers.MaxPooling2D(2, 2))

# second conv2d and maxpooling layer
model.add(layers.Conv2D(32, (3,3), activation='relu'))
model.add(layers.MaxPooling2D(2, 2))

# third conv2d and maxpooling layer
model.add(layers.Conv2D(128, (3,3), activation='relu'))
model.add(layers.MaxPooling2D(2, 2))

# fourth conv2d and maxpooling layer
model.add(layers.Conv2D(128, (3,3), activation='relu'))
model.add(layers.MaxPooling2D(2, 2))

# flattening the layer and adding droupout of 20%
model.add(layers.Flatten())
model.add(layers.Dropout(0.2))

# adding dense layer
model.add(layers.Dense(512, activation='relu'))

# adding dense layer
model.add(layers.Dense(264, activation='relu'))

# As binary classification hence 2 output layer
model.add(layers.Dense(2, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 78, 78, 64)        1792
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 39, 39, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 37, 37, 32)        18464
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 18, 18, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 128)       36992
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 6, 6, 128)         147584
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1152)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               590336
# _________________________________________________________________
# dense_10 (Dense)             (None, 264)               135432
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 530
# =================================================================
# Total params: 931,130
# Trainable params: 931,130
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
history = model.fit(train_generator, epochs=45, validation_data = validation_generator, verbose = 1)
# Out:
# Epoch 1/45
# 88/88 [==============================] - 144s 2s/step - loss: 0.6373 - accuracy: 0.6628 - val_loss: 0.3927 - val_accuracy: 0.8127
# Epoch 2/45
# 88/88 [==============================] - 213s 2s/step - loss: 0.4092 - accuracy: 0.8141 - val_loss: 0.3202 - val_accuracy: 0.8763
# Epoch 3/45
# 88/88 [==============================] - 141s 2s/step - loss: 0.3573 - accuracy: 0.8412 - val_loss: 0.2506 - val_accuracy: 0.9003
# Epoch 4/45
# 88/88 [==============================] - 142s 2s/step - loss: 0.3380 - accuracy: 0.8611 - val_loss: 0.3297 - val_accuracy: 0.8574
# Epoch 5/45
# 88/88 [==============================] - 142s 2s/step - loss: 0.3239 - accuracy: 0.8625 - val_loss: 0.2551 - val_accuracy: 0.9021
# Epoch 6/45
# 88/88 [==============================] - 143s 2s/step - loss: 0.2999 - accuracy: 0.8702 - val_loss: 0.2445 - val_accuracy: 0.9124
# Epoch 7/45
# 88/88 [==============================] - 142s 2s/step - loss: 0.3055 - accuracy: 0.8772 - val_loss: 0.4983 - val_accuracy: 0.7801
# Epoch 8/45
# 88/88 [==============================] - 142s 2s/step - loss: 0.2982 - accuracy: 0.8817 - val_loss: 0.2546 - val_accuracy: 0.9003
# Epoch 9/45
# 88/88 [==============================] - 141s 2s/step - loss: 0.2877 - accuracy: 0.8846 - val_loss: 0.3927 - val_accuracy: 0.8247
# Epoch 10/45
# 88/88 [==============================] - 141s 2s/step - loss: 0.2320 - accuracy: 0.9091 - val_loss: 0.2804 - val_accuracy: 0.9089
# Epoch 32/45
# 88/88 [==============================] - 141s 2s/step - loss: 0.2288 - accuracy: 0.9127 - val_loss: 0.2120 - val_accuracy: 0.9192
# Epoch 33/45
# 88/88 [==============================] - 141s 2s/step - loss: 0.2357 - accuracy: 0.9072 - val_loss: 0.4923 - val_accuracy: 0.8643
# Epoch 34/45
# 88/88 [==============================] - 141s 2s/step - loss: 0.2275 - accuracy: 0.9131 - val_loss: 0.3252 - val_accuracy: 0.8883
# Epoch 35/45
# 88/88 [==============================] - 140s 2s/step - loss: 0.2186 - accuracy: 0.9127 - val_loss: 0.2966 - val_accuracy: 0.8969
# Epoch 36/45
# 88/88 [==============================] - 141s 2s/step - loss: 0.2319 - accuracy: 0.9106 - val_loss: 0.2662 - val_accuracy: 0.9089
# Epoch 37/45
# 88/88 [==============================] - 141s 2s/step - loss: 0.2275 - accuracy: 0.9070 - val_loss: 0.6647 - val_accuracy: 0.8282
# Epoch 38/45
# 88/88 [==============================] - 140s 2s/step - loss: 0.2305 - accuracy: 0.9070 - val_loss: 0.2908 - val_accuracy: 0.8866
# Epoch 39/45
# 88/88 [==============================] - 140s 2s/step - loss: 0.2366 - accuracy: 0.9143 - val_loss: 0.2747 - val_accuracy: 0.8866
# Epoch 40/45
# 88/88 [==============================] - 141s 2s/step - loss: 0.2338 - accuracy: 0.9084 - val_loss: 0.2734 - val_accuracy: 0.8849
# Epoch 41/45
# 88/88 [==============================] - 140s 2s/step - loss: 0.2253 - accuracy: 0.9136 - val_loss: 0.2727 - val_accuracy: 0.9089
# Epoch 42/45
# 88/88 [==============================] - 141s 2s/step - loss: 0.2234 - accuracy: 0.9125 - val_loss: 0.2441 - val_accuracy: 0.9107
# Epoch 43/45
# 88/88 [==============================] - 141s 2s/step - loss: 0.2160 - accuracy: 0.9140 - val_loss: 0.6998 - val_accuracy: 0.8058
# Epoch 44/45
# 88/88 [==============================] - 140s 2s/step - loss: 0.2223 - accuracy: 0.9106 - val_loss: 0.2358 - val_accuracy: 0.9124
# Epoch 45/45
# 88/88 [==============================] - 140s 2s/step - loss: 0.2304 - accuracy: 0.9143 - val_loss: 0.4286 - val_accuracy: 0.8694

# %%
img_path_meme_true = 'dataset/train/meme_true/13.jpg'
img = mpimg.imread(img_path_meme_true)
plt.title("Meme")
plt.imshow(img)
plt.show()

img_path_meme_false = 'dataset/train/meme_false/14.jpg'
img = mpimg.imread(img_path_meme_false)
plt.title("Not a meme")
plt.imshow(img)
plt.show()

# %%
from tensorflow.keras.models import load_model

# %%
model.save('my_model.h5') 
# model = load_model('my_model.h5')

# %%
# taking testing image from test set
path_im_meme_true = 'dataset/test/meme_true/3092.jpg'
path_im_meme_false = 'dataset/test/meme_false/3080.jpg'

img1 = image.load_img(path_im_pneumonia, target_size=(80, 80))
img2 = image.load_img(path_im_normal, target_size=(80, 80))

# converting to array
imToArr1 = image.img_to_array(img1)
imToArr2 = image.img_to_array(img2)

# expanding layer
imToArr1 = np.expand_dims(imToArr1, axis=0)
imToArr2 = np.expand_dims(imToArr2, axis=0)

# stacking images
images = np.vstack([imToArr1,imToArr2])

#predicting
predicted_class = model.predict(images, batch_size=1)
print(predicted_class)
